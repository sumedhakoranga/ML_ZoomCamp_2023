# %% [markdown]
# ##Session #1 HOMEWORK

# %% [markdown]
# ###Initialization

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##Question1
# #####What's the version of Pandas that you installed?

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# ### Getting the Data

# %%
df= pd.read_csv('housing.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ##Questions2
# #####How many columns are in the dataset?

# %%
len(df.columns)
# Out:
# 10

# %% [markdown]
# ##Questions3
# #####Which columns in the dataset have missing values?

# %%
df.isnull().any()
# Out:
# longitude             False
# latitude              False
# housing_median_age    False
# total_rooms           False
# total_bedrooms         True
# population            False
# households            False
# median_income         False
# median_house_value    False
# ocean_proximity       False
# dtype: bool

# %% [markdown]
# ##Question4
# #####How many unique values does the ocean_proximity column have?

# %%
df['ocean_proximity'].nunique()
# Out:
# 5

# %% [markdown]
# ##Question5
# #####What's the average value of the median_house_value for the houses located near the bay?

# %%
z= df.loc[df['ocean_proximity'] == 'NEAR BAY']

# %%
z
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 19067    -122.45     38.28                20.0       3306.0           503.0
# 19068    -122.47     38.29                14.0       3732.0           846.0
# 19069    -122.45     38.27                25.0       5024.0           881.0
# 19077    -122.49     38.27                 8.0       5092.0           988.0
# 19104    -122.51     38.17                 8.0       5875.0          1115.0
#
# ...

# %%
z['median_house_value'].mean()
# Out:
# 259212.31179039303

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# ##Question 6
# #####Calculate the average of total_bedrooms column in the dataset.Use the fillna method to fill the missing values in total_bedrooms with the mean value from the previous step.Now, calculate the average of total_bedrooms again.Has it changed?

# %%
df['total_bedrooms'].mean()
# Out:
# 537.8705570251938

# %%
df.fillna(df.mean(numeric_only=True).round(3), inplace=True)

# %%
df['total_bedrooms'].mean()
# Out:
# 537.8705570251938

# %% [markdown]
# ##Question 7
# #####Select all the options located on islands.
# #####Select only columns housing_median_age, total_rooms, total_bedrooms.Get the underlying NumPy array. Let's call it X.
# #####Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
# #####Compute the inverse of XTX.
# #####Create an array y with values **[950, 1300, 800, 1000, 1300].**
# #####Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
# #####What's the value of the last element of w?

# %%
df1= df.loc[df['ocean_proximity'] == 'ISLAND']

# %%
df1
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8314    -118.32     33.35                27.0       1675.0           521.0
# 8315    -118.33     33.34                52.0       2359.0           591.0
# 8316    -118.32     33.33                52.0       2127.0           512.0
# 8317    -118.32     33.34                52.0        996.0           264.0
# 8318    -118.48     33.43                29.0        716.0           214.0
#
#       population  households  median_income  median_house_value  \
# 8314       744.0       331.0         2.1579            450000.0
# 8315      1100.0       431.0         2.8333            414700.0
# 8316       733.0       288.0         3.3906            300000.0
# 8317       341.0       160.0         2.7361            450000.0
# 8318       422.0       173.0         2.6042            287500.0
#
#      ocean_proximity
# 8314          ISLAND
# 8315          ISLAND
# 8316          ISLAND
# 8317          ISLAND
# ...

# %%
df2=df1[['housing_median_age','total_rooms','total_bedrooms']]

# %%
df2
# Out:
#       housing_median_age  total_rooms  total_bedrooms
# 8314                27.0       1675.0           521.0
# 8315                52.0       2359.0           591.0
# 8316                52.0       2127.0           512.0
# 8317                52.0        996.0           264.0
# 8318                29.0        716.0           214.0

# %%
X=df2.to_numpy()

# %%
X
# Out:
# array([[  27., 1675.,  521.],
#        [  52., 2359.,  591.],
#        [  52., 2127.,  512.],
#        [  52.,  996.,  264.],
#        [  29.,  716.,  214.]])

# %%
T=X.transpose()

# %%
T
# Out:
# array([[  27.,   52.,   52.,   52.,   29.],
#        [1675., 2359., 2127.,  996.,  716.],
#        [ 521.,  591.,  512.,  264.,  214.]])

# %%
XTX=T.dot(X)

# %%
XTX
# Out:
# array([[9.6820000e+03, 3.5105300e+05, 9.1357000e+04],
#        [3.5105300e+05, 1.4399307e+07, 3.7720360e+06],
#        [9.1357000e+04, 3.7720360e+06, 9.9835800e+05]])

# %%
inv_x=np.linalg.pinv(XTX)

# %%
inv_x
# Out:
# array([[ 9.19403586e-04, -3.66412216e-05,  5.43072261e-05],
#        [-3.66412216e-05,  8.23303633e-06, -2.77534485e-05],
#        [ 5.43072261e-05, -2.77534485e-05,  1.00891325e-04]])

# %%
y=pd.array([950, 1300, 800, 1000, 1300])

# %%
y
# Out:
# <IntegerArray>
# [950, 1300, 800, 1000, 1300]
# Length: 5, dtype: Int64

# %%
s=inv_x.dot(T)

# %%
s
# Out:
# array([[-0.00825608, -0.00653208, -0.00232159,  0.02565144,  0.01204934],
#        [-0.00165852,  0.0011141 ,  0.00139656, -0.00103215, -0.00110698],
#        [ 0.00754365, -0.00301964, -0.00455125,  0.00181685,  0.00329418]])

# %%
w=s.dot(y)

# %%
w
# Out:
# array([23.12330961215161, -1.4812418324049916, 5.699229455065494],
#       dtype=object)
